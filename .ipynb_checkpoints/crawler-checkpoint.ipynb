# %%
import requests
res = requests.get("https://ecpm.tanx.com/ex?i=mm_12852562_1778064_39860751&cb=jsonp_callback_75959&callback=&userid=&o=&f=&n=&r=https%3A%2F%2Fwww.msn.cn%2Fspartan%2Fientp%3Flocale%3Dzh-CN%26market%3DCN%26enableregulatorypsm%3D0%26enablecpsm%3D0%26NTLogo%3D1%26IsFRE%3D0%26pc%3DEUPP_ASTE&cg=a981aaee7644301b1f2f2ca5cd241882&pvid=a77f5af8d3420e6c885d2bc60d761cd9&u=https%3A%2F%2Fai.taobao.com%2F%3Fpid%3Dmm_121122127_40670994_68992200449&psl=1&nk=&sk=&refpid=&fp=1.HawLsQkgyJ0KOS79f84qfzy7lLgVAqL3Moeb3nXeH4_HzAy0XxFIv0.utf-8.oxOg3bS52gtOiK_otLGJZOgwJUNVyhnPUA_KQ.Q.cn8lf3")
print (res.text)
# Out:
# jsonp_callback_75959({"acookie":"","adboardtype":"2","bannermaker":"","clickurl":"https://click.mz.simba.taobao.com/ecpm?e=wiIUuc1YwDsPO53EdXrfSxsQmLP5zomM%2BBxRSKMgorciGFZKx1bK%2B0E4Apk3tEbcxJEOOamOzx6u7Mz64u5sbMS0dc6sqr6dtbR9sxq9q4jPdxtGLmpJMATE2Vszfxg%2FC5l%2F4LobPApXVh%2FNkGECYmnt%2FfbN1K%2BzaU1mqWlB9KCJNP9IkbYSTSTevyCWTprv0RSeceTguFftEcaTI9TedU2n2D73W486jvM89i6vtVpvrym4x2XVmpmjplPSduGDPWeBoT0LSCW7BHmJC0Pg%2FOdFwBLyXl%2FdYUAzu2LosDqugsumAUs25ndM7nnuaKOoMBB%2Bb9HtVIxSB3wNh5xqN8MGcp%2BcgDO5PyjST64pbW528ZNeTjDXxeqOwPMbc6LIiqF068fUO8yZBI%2F15Mj4DzD%2FSlBDqtScyNlEoDiDiYGQRI77PL%2B5M%2F2LkpHIcvcB%2FKIBRtEefQKdK45KV7slVBPUqP%2FUE31yjxMm4XrbYNk%3D&u=https%3A%2F%2Fdetail.tmall.com%2Fitem.htm%3Fid%3D523765503152%26sku_properties%3D122216927%3A77835123&k=493","data":"https://img.alicdn.com/simba/img/TB1B3MpiRcHL1JjSZFBSuuiGXXa.jpg","distype":"1","fvs":"","height":"280","pid":"mm_12852562_1778064_39860751","title":"","webwidth":"","width":"520"})

# %%
import requests
res = requests.get("https://s.1688.com/kq/-CCD4B1A6CDF8B1A3CEC2B1AD.html")
print (res.text)
# Out:
# <!DOCTYPE html>
# <html>
# <head>
# <meta http-equiv="Content-Type" content="text/html; charset=GBK" />
# <meta http-equiv="Cache-Control" content="no-siteapp" />
# <meta http-equiv="Cache-Control" content="no-transform" />
# <meta name="applicable-device" content="pc">
# <meta property="og:type" content="image"/>
#  <meta property="og:image" content="https://cbu01.alicdn.com/img/ibank/2018/209/458/8704854902_1259505829.220x220.jpg"/>
#
# <title>【淘宝网保温杯】_淘宝网保温杯品牌/图片/价格_淘宝网保温杯批发_阿里巴巴</title>
# <meta name="keywords" content="淘宝网保温杯"/>
# <meta name="description" content="找淘宝网保温杯，上阿里巴巴1688.com，全球领先采购批发平台，阿里巴巴为你找到22条淘宝网保温杯优质商品，包括品牌，价格，图片，厂家，产地，材料等，海量淘宝网保温杯,供您挑选，阿里巴巴批发采购一站式全程服务,让生意变的温馨放心。"/>
#
# <meta name="mobile-agent" content="format=html5;url=https://m.1688.com/kq/-CCD4B1A6CDF8B1A3CEC2B1AD.html">
# <meta name="mobile-agent" content="format=xhtml;url=https://m.1688.com/kq/-CCD4B1A6CDF8B1A3CEC2B1AD.html">
# ...

# %%
import re
rea=re.findall(r"<title>(.+?)</title>",res.text)
print("\nPage title is: ",rea[0])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-9fc154aec190> in <module>()
#       1 import re
# ----> 2 rea=re.findall(r"<title>(.+?)</title>",res.text)
#       3 print("\nPage title is: ",rea[0])
#
# NameError: name 'res' is not defined

# %%
import requests
from bs4 import BeautifulSoup
res = requests.get("https://s.1688.com/kq/-CCD4B1A6CDF8B1A3CEC2B1AD.html")
soup = BeautifulSoup(res.text)
for item in soup.select('.div'):
    print (item.select('font'))[0].text.strip(),

# %%
import requests
payload = {

   Date: Wed, 19 Dec 2018 09:59:08 GMT
   Server: Tengine/2.1.2
   X-AspNet-Version: 4.0.30319
   X-Powered-By: ASP.NET
}
res = requests.post("http://trains.ctrip.com/TrainBooking/Ajax/SearchGradListHandler.ashx?Action=GetGrabTicketSucRateInfoJava",data = payload)
print (res.text)
# Out:
#   File "<ipython-input-14-58e32dd2a5d4>", line 4
#     Date: Wed, 19 Dec 2018 09:59:08 GMT
#                     ^
# SyntaxError: invalid syntax

# %%
import requests
res = requests.get("https://s.1688.com/kq/-CCD4B1A6CDF8B1A3CEC2B1AD.html")
print (res.text)
# Out:
# <!DOCTYPE html>
# <html>
# <head>
# <meta http-equiv="Content-Type" content="text/html; charset=GBK" />
# <meta http-equiv="Cache-Control" content="no-siteapp" />
# <meta http-equiv="Cache-Control" content="no-transform" />
# <meta name="applicable-device" content="pc">
# <meta property="og:type" content="image"/>
#  <meta property="og:image" content="https://cbu01.alicdn.com/img/ibank/2018/209/458/8704854902_1259505829.220x220.jpg"/>
#
# <title>【淘宝网保温杯】_淘宝网保温杯品牌/图片/价格_淘宝网保温杯批发_阿里巴巴</title>
# <meta name="keywords" content="淘宝网保温杯"/>
# <meta name="description" content="找淘宝网保温杯，上阿里巴巴1688.com，全球领先采购批发平台，阿里巴巴为你找到23条淘宝网保温杯优质商品，包括品牌，价格，图片，厂家，产地，材料等，海量淘宝网保温杯,供您挑选，阿里巴巴批发采购一站式全程服务,让生意变的温馨放心。"/>
#
# <meta name="mobile-agent" content="format=html5;url=https://m.1688.com/kq/-CCD4B1A6CDF8B1A3CEC2B1AD.html">
# <meta name="mobile-agent" content="format=xhtml;url=https://m.1688.com/kq/-CCD4B1A6CDF8B1A3CEC2B1AD.html">
# ...

# %%
import re
rea=re.findall(r"<title>(.+?)</title>",res.text)
print("\nPage title is: ",rea[0])
# Out:
# Page title is:  【淘宝网保温杯】_淘宝网保温杯品牌/图片/价格_淘宝网保温杯批发_阿里巴巴

# %%
reb=re.findall(r"<p>(.*?)</p>",res.text,flags=re.DOTALL)
print("\nPage paragraph is:",reb[0])
# Out:
# Page paragraph is:
# 阿里巴巴为您找到23条淘宝网保温杯产品的厂家、货源、报价、批发、采购等信息，您还可以找更多淘宝网保温杯、儿童保温杯、进口保温杯的产品货源、厂家等信息

# %%
rec=re.findall(r'href="(.*?)"',res.text)
print("\nAll links:",rec)
# Out:
# All links: ['https://m.1688.com/kq/-CCD4B1A6CDF8B1A3CEC2B1AD.html', 'https://www.1688.com/favicon.ico', '//astyle.alicdn.com/??app/search/css/list/cml/appbase/base.min.css,app/search/css/list/plugins/qingguo/layout/layout.css,app/search/css/list/plugins/qingguo/recommendwords/recommendwords.min.css,app/search/css/list/plugins/qingguo/offerresult/city/cityOfferResult.css,app/searchweb/cml/offerresult/pkg-a/css/offerresult.css,app/searchweb/cml/widget/common/css/ui.css,app/searchweb/common/widget/css/ui.css,app/search/css/list/plugins/qingguo/similar/ui.css,app/opensearch/cml/scrolltop/pkg-a/css/scrolltop.css,fdevlib/css/lofty/ui/button/1.0/front/button-min.css,app/search/css/list/plugins/qingguo/moreinfo/moreinfo.css,app/search/css/list/plugins/qingguo/bottomrecommend/bottomrecommend.css,app/search/css/list/plugins/qingguo/searchbar/rwd.searchbar.css,app/search/css/list/plugins/qingguo/jiage/searchbar/searchbar.css?_v=36a9aaad5016f6900ff950d5a17fa2a5.css', 'https://detail.1688.com/off
# ...

# %%
from bs4 import BeautifulSoup
from urllib.request import urlopen
html=urlopen("https://s.1688.com/kq/-CCD4B1A6CDF8B1A3CEC2B1AD.html").read().decode()
print (html)
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-14-39bbfc1d3476> in <module>()
#       1 from bs4 import BeautifulSoup
#       2 from urllib.request import urlopen
# ----> 3 html=urlopen("https://s.1688.com/kq/-CCD4B1A6CDF8B1A3CEC2B1AD.html").read().decode()
#       4 print (html)
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xa1 in position 444: invalid start byte

# %%
from bs4 import BeautifulSoup
import requests
html = requests.get("https://s.1688.com/kq/-CCD4B1A6CDF8B1A3CEC2B1AD.html")
print (html.text)
# Out:
# <!DOCTYPE html>
# <html>
# <head>
# <meta http-equiv="Content-Type" content="text/html; charset=GBK" />
# <meta http-equiv="Cache-Control" content="no-siteapp" />
# <meta http-equiv="Cache-Control" content="no-transform" />
# <meta name="applicable-device" content="pc">
# <meta property="og:type" content="image"/>
#  <meta property="og:image" content="https://cbu01.alicdn.com/img/ibank/2018/209/458/8704854902_1259505829.220x220.jpg"/>
#
# <title>【淘宝网保温杯】_淘宝网保温杯品牌/图片/价格_淘宝网保温杯批发_阿里巴巴</title>
# <meta name="keywords" content="淘宝网保温杯"/>
# <meta name="description" content="找淘宝网保温杯，上阿里巴巴1688.com，全球领先采购批发平台，阿里巴巴为你找到23条淘宝网保温杯优质商品，包括品牌，价格，图片，厂家，产地，材料等，海量淘宝网保温杯,供您挑选，阿里巴巴批发采购一站式全程服务,让生意变的温馨放心。"/>
#
# <meta name="mobile-agent" content="format=html5;url=https://m.1688.com/kq/-CCD4B1A6CDF8B1A3CEC2B1AD.html">
# <meta name="mobile-agent" content="format=xhtml;url=https://m.1688.com/kq/-CCD4B1A6CDF8B1A3CEC2B1AD.html">
# ...

# %%
soup=BeautifulSoup(html.text,features='lxml')
print(soup.h1)
# Out:
# None

# %%
print("\n",soup.p1)
# Out:
#  None

# %%
print(soup.p)
# Out:
# None

# %%
soup=BeautifulSoup(html.text)

# %%
print(soup.p)
# Out:
# None

# %%
print(soup.title)
# Out:
# <title>【淘宝网保温杯】_淘宝网保温杯品牌/图片/价格_淘宝网保温杯批发_阿里巴巴</title>

# %%
for link in soup.find_all('a'):
    print(link.get('href'))
# Out:
# https://detail.1688.com/offer/546361216326.html
# https://detail.1688.com/offer/546361216326.html
# https://fuyunlaitaoci.1688.com
# https://fuyunlaitaoci.1688.com
# #
# https://detail.1688.com/offer/566723508005.html
# https://detail.1688.com/offer/566723508005.html
# https://shop7f1j33129v488.1688.com
# https://shop7f1j33129v488.1688.com
# #
# https://detail.1688.com/offer/1158319306.html
# https://detail.1688.com/offer/1158319306.html
# https://sdlyfjf.1688.com
# https://sdlyfjf.1688.com
# #
# https://detail.1688.com/offer/566831827229.html
# https://detail.1688.com/offer/566831827229.html
# https://kunhong.1688.com
# https://kunhong.1688.com
# #
# https://detail.1688.com/offer/547112438529.html
# https://detail.1688.com/offer/547112438529.html
# https://dvorak.1688.com
# https://dvorak.1688.com
# #
# https://detail.1688.com/offer/566828163783.html
# https://detail.1688.com/offer/566828163783.html
# https://kunhong.1688.com
# https://kunhong.1688.com
# #
# ...

# %%
all_href=soup.find_all('a')
all_href=[l["href"] for l in all_href]
print('\n',all_href)
# Out:
#  ['https://detail.1688.com/offer/546361216326.html', 'https://detail.1688.com/offer/546361216326.html', 'https://fuyunlaitaoci.1688.com', 'https://fuyunlaitaoci.1688.com', '#', 'https://detail.1688.com/offer/566723508005.html', 'https://detail.1688.com/offer/566723508005.html', 'https://shop7f1j33129v488.1688.com', 'https://shop7f1j33129v488.1688.com', '#', 'https://detail.1688.com/offer/1158319306.html', 'https://detail.1688.com/offer/1158319306.html', 'https://sdlyfjf.1688.com', 'https://sdlyfjf.1688.com', '#', 'https://detail.1688.com/offer/566831827229.html', 'https://detail.1688.com/offer/566831827229.html', 'https://kunhong.1688.com', 'https://kunhong.1688.com', '#', 'https://detail.1688.com/offer/547112438529.html', 'https://detail.1688.com/offer/547112438529.html', 'https://dvorak.1688.com', 'https://dvorak.1688.com', '#', 'https://detail.1688.com/offer/566828163783.html', 'https://detail.1688.com/offer/566828163783.html', 'https://kunhong.1688.com', 'https://kunhong.1688.com
# ...

# %%
print (soup.get_text())
# Out:
# 【淘宝网保温杯】_淘宝网保温杯品牌/图片/价格_淘宝网保温杯批发_阿里巴巴
#
#
#
#
#
#
#
# var asyncResource={"searchweb":{"css":[],"js":["//astyle.alicdn.com/??app/search/js/list/cml/appbase/base.min.js,app/search/js/list/cml/global/default/config.js,app/search/js/list/cml/widget/alitalk.js,app/search/js/list/cml/offerresult/common/alitalk.js,fdevlib/js/lofty/lang/attribute.js,fdevlib/js/lofty/lang/observer.js,fdevlib/js/lofty/lang/pluginhost.js,fdevlib/js/lofty/lang/base.js,fdevlib/js/lofty/ui/widget/1.0/widget.js,fdevlib/js/lofty/util/template/1.0/template.js,fdevlib/js/lofty/util/template/1.0/tplhandler.js,fdevlib/js/lofty/util/misc/2.0/misc.js,fdevlib/js/lofty/ui/sidebar/2.0/sidebar.js,app/opensearch/cml/pageconfig/common/js/utility.js,app/opensearch/cml/scrolltop/pkg-a/js/scrolltop.js?_v=c10458353ffa8a964d3bcf0fceebce25.js"]},"search":{"css":[],"js":["//astyle.alicdn.com/??app/search/js/main/common/base/utility-amd.js,app/search/js/list/plugins/qingguo/clickmod.js?_v=f7269f0bf8aacbba233d1fa5438ef8db.js"]}};
#
#
#
# ...

# %%
from bs4 import BeautifulSoup
import requests
html=requests.get("https://baike.baidu.com/item/网络爬虫/5162711?fr=aladdin")
print(html.text)
# Out:
# ---------------------------------------------------------------------------
# TooManyRedirects                          Traceback (most recent call last)
# <ipython-input-27-191aab775b16> in <module>()
#       1 from bs4 import BeautifulSoup
#       2 import requests
# ----> 3 html=requests.get("https://baike.baidu.com/item/网络爬虫/5162711?fr=aladdin")
#       4 print(html.text)
#
# E:\anaconda3\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      70
#      71     kwargs.setdefault('allow_redirects', True)
# ---> 72     return request('get', url, params=params, **kwargs)
#      73
#      74
#
# E:\anaconda3\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      56     # cases, and look like a memory leak in others.
#      57     with sessions.Session() as session:
# ---> 58         return session.request(method=method, url=url, **kwargs)
#      59
#      60
#
# ...

# %%
from bs4 import BeautifulSoup
import requests
r = requests.get("https://baike.baidu.com/item/网络爬虫/5162711?fr=aladdin")
print(r.text)
# Out:
# ---------------------------------------------------------------------------
# TooManyRedirects                          Traceback (most recent call last)
# <ipython-input-38-cfa252d566df> in <module>()
#       1 from bs4 import BeautifulSoup
#       2 import requests
# ----> 3 r = requests.get("https://baike.baidu.com/item/网络爬虫/5162711?fr=aladdin")
#       4 print(r.text)
#
# E:\anaconda3\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      70
#      71     kwargs.setdefault('allow_redirects', True)
# ---> 72     return request('get', url, params=params, **kwargs)
#      73
#      74
#
# E:\anaconda3\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      56     # cases, and look like a memory leak in others.
#      57     with sessions.Session() as session:
# ---> 58         return session.request(method=method, url=url, **kwargs)
#      59
#      60
#
# ...

# %%
from bs4 import BeautifulSoup
from urllib.request import urlopen
html=urlopen("https://baike.baidu.com/item/网络爬虫/5162711?fr=aladdin").read().decode("utf-8")
print (html)
# Out:
# ---------------------------------------------------------------------------
# UnicodeEncodeError                        Traceback (most recent call last)
# <ipython-input-36-654d72a02fe6> in <module>()
#       1 from bs4 import BeautifulSoup
#       2 from urllib.request import urlopen
# ----> 3 html=urlopen("https://baike.baidu.com/item/网络爬虫/5162711?fr=aladdin").read().decode("utf-8")
#       4 print (html)
#
# E:\anaconda3\lib\urllib\request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     220     else:
#     221         opener = _opener
# --> 222     return opener.open(url, data, timeout)
#     223
#     224 def install_opener(opener):
#
# E:\anaconda3\lib\urllib\request.py in open(self, fullurl, data, timeout)
#     523             req = meth(req)
#     524
# --> 525         response = self._open(req, data)
#     526
#     527         # post-process response
#
# E:\anaconda3\lib\urllib\request.py in _open(self, req, data)
# ...

# %%
from bs4 import BeautifulSoup
import requests
r = requests.get("https://www.baidu.com/s?word=%E7%88%AC%E8%99%AB%E6%95%99%E7%A8%8B&tn=93601592_hao_pg&ie=utf-8&sc=UWY4n1msnHR4n-qCmyqxTAThIjYkPHfdrHTsnWcYnj6sFhnqpA7EnHc1Fh7W5HD3rjfsnjbLn1T&ssl_sample=s_11%2Cs_108&srcqid=2703005706910036497&H123Tmp=nu")
print(r.text)
# Out:
# <html>
# <head>
# 	<script>
# 		location.replace(location.href.replace("https://","http://"));
# 	</script>
# </head>
# <body>
# 	<noscript><meta http-equiv="refresh" content="0;url=http://www.baidu.com/"></noscript>
# </body>
# </html>

# %%
from bs4 import BeautifulSoup
import requests
r = requests.get("https://baike.baidu.com/item/机器学习/217599?fr=aladdin")
print(r.text)
# Out:
# ---------------------------------------------------------------------------
# TooManyRedirects                          Traceback (most recent call last)
# <ipython-input-40-a29184ce807f> in <module>()
#       1 from bs4 import BeautifulSoup
#       2 import requests
# ----> 3 r = requests.get("https://baike.baidu.com/item/机器学习/217599?fr=aladdin")
#       4 print(r.text)
#
# E:\anaconda3\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      70
#      71     kwargs.setdefault('allow_redirects', True)
# ---> 72     return request('get', url, params=params, **kwargs)
#      73
#      74
#
# E:\anaconda3\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      56     # cases, and look like a memory leak in others.
#      57     with sessions.Session() as session:
# ---> 58         return session.request(method=method, url=url, **kwargs)
#      59
#      60
#
# ...

# %%
from bs4 import BeautifulSoup
import requests
r = requests.get("https://blog.csdn.net/hohaizx/article/details/80584307")
print(r.text)
# Out:
# <!DOCTYPE html>
# <html lang="zh-CN">
# <head>
#     <meta charset="UTF-8">
#     <link rel="canonical" href="https://blog.csdn.net/hohaizx/article/details/80584307"/>
#     <meta http-equiv="content-type" content="text/html; charset=utf-8">
#     <meta name="renderer" content="webkit"/>
#     <meta name="force-rendering" content="webkit"/>
#     <meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1"/>
#     <meta name="viewport" content="width=device-width, initial-scale=1.0, minimum-scale=1.0, maximum-scale=1.0, user-scalable=no">
#     <meta name="apple-mobile-web-app-status-bar-style" content="black">
#     <meta name="referrer" content="always">
#     <meta http-equiv="Cache-Control" content="no-siteapp" /><link rel="alternate" media="handheld" href="#" />
#     <meta name="shenma-site-verification" content="5a59773ab8077d4a62bf469ab966a63b_1497598848">
# ...

# %%
base_url="https://blog.csdn.net/hohaizx/article/details/80584307"
his=["https://csdnimg.cn/public/favicon.ico"]
url=base_url+his[-1]
soup=BeautifulSoup(html)
print(soup.find('h1').get_text(),'url:',his[-1])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-45-600b7ff23783> in <module>()
#       2 his=["https://csdnimg.cn/public/favicon.ico"]
#       3 url=base_url+his[-1]
# ----> 4 soup=BeautifulSoup(html)
#       5 print(soup.find('h1').get_text(),'url:',his[-1])
#
# E:\anaconda3\lib\site-packages\bs4\__init__.py in __init__(self, markup, features, builder, parse_only, from_encoding, exclude_encodings, **kwargs)
#     244         if hasattr(markup, 'read'):        # It's a file-type object.
#     245             markup = markup.read()
# --> 246         elif len(markup) <= 256 and (
#     247                 (isinstance(markup, bytes) and not b'<' in markup)
#     248                 or (isinstance(markup, str) and not '<' in markup)
#
# TypeError: object of type 'Response' has no len()

# %%
from urllib.request import urlopen
html=urlopen("https://morvanzhou.github.io/static/scraping/basic-structure.html").read().decode('utf-8')
print(html)
# Out:
# <!DOCTYPE html>
# <html lang="cn">
# <head>
# 	<meta charset="UTF-8">
# 	<title>Scraping tutorial 1 | 莫烦Python</title>
# 	<link rel="icon" href="https://morvanzhou.github.io/static/img/description/tab_icon.png">
# </head>
# <body>
# 	<h1>爬虫测试1</h1>
# 	<p>
# 		这是一个在 <a href="https://morvanzhou.github.io/">莫烦Python</a>
# 		<a href="https://morvanzhou.github.io/tutorials/data-manipulation/scraping/">爬虫教程</a> 中的简单测试.
# 	</p>
#
# </body>
# </html>

# %%
s='我爱你'
s=u'我爱你'.encode('utf-8')

# %%
type('我爱你')
# Out:
# str

# %%
len(s)
# Out:
# 9

# %%
s
# Out:
# b'\xe6\x88\x91\xe7\x88\xb1\xe4\xbd\xa0'

# %%
type(s)
# Out:
# str

# %%
s = u'中文'

# %%
type(s)
# Out:
# str

# %%
s
# Out:
# '中文'

# %%
len(s)
# Out:
# 2

# %%
u'中文'
# Out:
# '中文'

# %%
unicode
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-449e7d699f5b> in <module>()
# ----> 1 unicode
#
# NameError: name 'unicode' is not defined

# %%
isinstance(u'中文',unicode)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-6045a13bd95d> in <module>()
# ----> 1 isinstance(u'中文',unicode)
#
# NameError: name 'unicode' is not defined

# %%
import requests
import urllib.parse

word='网络爬虫'
word=urllib.parse.quote(word)
url='https://baike.baidu.com/item/%s/5162711'%word
print(url)
# Out:
# https://baike.baidu.com/item/%E7%BD%91%E7%BB%9C%E7%88%AC%E8%99%AB/5162711

# %%
s=requests.session()
s.headers['User-Agent']='Mozilla/5.0 (Windows NT 10.0; WOW64; Trident/7.0; rv:11.0) like Gecko'
res=s.get("https://baike.baidu.com/item/%E7%BD%91%E7%BB%9C%E7%88%AC%E8%99%AB/5162711".content.decode('utf-8')
print(res.text)
# Out:
#   File "<ipython-input-44-e69ac75b311f>", line 4
#     print(res.text)
#         ^
# SyntaxError: invalid syntax

# %%
import sys

# %%
sys.getdefaultencoding()
# Out:
# 'utf-8'

# %%
# -*- coding: utf-8 -*-
from urllib.request import urlopen
import requests
import urllib.parse

word='网络爬虫'
word=urllib.parse.quote(word)
url='https://baike.baidu.com/item/%s/5162711'%word
print(url)
a=urlopen(url).read().decode('utf-8')
print(a)
# Out:
# https://baike.baidu.com/item/%E7%BD%91%E7%BB%9C%E7%88%AC%E8%99%AB/5162711
# <!DOCTYPE html>
# <!--STATUS OK-->
# <html>
#
#
#
# <head>
# <meta charset="UTF-8">
# <meta http-equiv="X-UA-Compatible" content="IE=Edge" />
# <meta name="referrer" content="always" />
# <meta name="description" content="网络爬虫（又被称为网页蜘蛛，网络机器人，在FOAF社区中间，更经常的称为网页追逐者），是一种按照一定的规则，自动地抓取万维网信息的程序或者脚本。另外一些不常使用的名字还有蚂蚁、自动索引、模拟程序或者蠕虫。...">
# <title>网络爬虫_百度百科</title>
# <link rel="shortcut icon" href="/favicon.ico" type="image/x-icon" />
# <link rel="icon" sizes="any" mask href="//www.baidu.com/img/baidu.svg">
#
# <meta name="keywords" content="网络爬虫 爬虫 网页蜘蛛 爬虫程序 蜘蛛程序 搜索引擎蜘蛛 蜘蛛 网络蜘蛛 网络爬虫产生背景 网络爬虫面临的问题 网络爬虫分类 网络爬虫抓取目标分类 网络爬虫网页搜索策略 网络爬虫网页分析算法 网络爬虫补充">
# <meta name="image" content="https://bkssl.bdimg.com/cms/static/baike.png">
# <script type="text/javascript">
#   // 配置 PD 监控。
#   window.alogObjectConfig = {
#     product: '103',
#     page: '103_1',
#     speed: {
#       sample: '0.008'
#     },
#     monkey: {
# ...

# %%
from bs4 import BeautifulSoup
import re
import random
base_url="https://baike.baidu.com"
his=["/item/%E7%BD%91%E7%BB%9C%E7%88%AC%E8%99%AB/5162711"]

for i in range(20):
    url=base_url+his[-1]
    html=urlopen(url).read().decode('utf-8')
    soup=BeautifulSoup(html,features='lxml')
    print(i,soup.find('h1').get_text(),' url:',his[-1])

    sub_urls=soup.find_all("a",{"target":"_blank","href":re.compile("/item/(%.{2})+$")})
    if len(sub_urls)!=0:
        his.append(random.sample(sub_urls,1)[0]['href'])
    else:
        his.pop()
# Out:
# 0 网络爬虫  url: /item/%E7%BD%91%E7%BB%9C%E7%88%AC%E8%99%AB/5162711
# 1 锚文本  url: /item/%E9%94%9A%E6%96%87%E6%9C%AC
# 2 官方网站  url: /item/%E5%AE%98%E6%96%B9%E7%BD%91%E7%AB%99
# 3 品牌形象  url: /item/%E5%93%81%E7%89%8C%E5%BD%A2%E8%B1%A1
# 4 品牌经营  url: /item/%E5%93%81%E7%89%8C%E7%BB%8F%E8%90%A5
# 5 长松咨询  url: /item/%E9%95%BF%E6%9D%BE%E5%92%A8%E8%AF%A2
# 6 刘文举  url: /item/%E5%88%98%E6%96%87%E4%B8%BE
# 7 百度百科：多义词  url: /item/%E7%99%BE%E5%BA%A6%E7%99%BE%E7%A7%91%EF%BC%9A%E5%A4%9A%E4%B9%89%E8%AF%8D
# 8 赵氏孤儿大报仇  url: /item/%E8%B5%B5%E6%B0%8F%E5%AD%A4%E5%84%BF
# 9 义项  url: /item/%E4%B9%89%E9%A1%B9
# 10 保尔·柯察金  url: /item/%E4%BF%9D%E5%B0%94%C2%B7%E6%9F%AF%E5%AF%9F%E9%87%91
# 11 钢铁是怎样炼成的  url: /item/%E9%92%A2%E9%93%81%E6%98%AF%E6%80%8E%E6%A0%B7%E7%82%BC%E6%88%90%E7%9A%84
# 12 北京青年报  url: /item/%E5%8C%97%E4%BA%AC%E9%9D%92%E5%B9%B4%E6%8A%A5
# 13 共青团北京市委员会  url: /item/%E5%85%B1%E9%9D%92%E5%9B%A2%E5%8C%97%E4%BA%AC%E5%B8%82%E5%A7%94%E5%91%98%E4%BC%9A
# 14 黄克瀛  url: /item/%E9%BB%84%E5%85%8B%E7%80%9B
# ...

# %%
print(url)
# Out:
# https://baike.baidu.com/item/%E7%BD%91%E7%BB%9C%E7%88%AC%E8%99%AB/5162711

# %%
html=urlopen(url).read().decode('utf-8')
soup=BeautifulSoup(html,features='lxml')
print(soup.find('h1').get_text(),' url:',his[-1])
# Out:
# 网络爬虫  url: /item/%E7%BD%91%E7%BB%9C%E7%88%AC%E8%99%AB/5162711

# %%
sub_urls=soup.find_all("a",{"target":"_blank","href":re.compile("/item/(%.{2})+$")})
if len(sub_urls)!=0:
    his.append(random.sample(sub_urls,1)[0]['href'])
else:
    his.pop()
print(his)
# Out:
# ['/item/%E7%BD%91%E7%BB%9C%E7%88%AC%E8%99%AB/5162711', '/item/%E9%94%9A%E6%96%87%E6%9C%AC', '/item/%E5%AE%98%E6%96%B9%E7%BD%91%E7%AB%99', '/item/%E5%93%81%E7%89%8C%E5%BD%A2%E8%B1%A1', '/item/%E5%93%81%E7%89%8C%E7%BB%8F%E8%90%A5', '/item/%E9%95%BF%E6%9D%BE%E5%92%A8%E8%AF%A2', '/item/%E5%88%98%E6%96%87%E4%B8%BE', '/item/%E7%99%BE%E5%BA%A6%E7%99%BE%E7%A7%91%EF%BC%9A%E5%A4%9A%E4%B9%89%E8%AF%8D', '/item/%E8%B5%B5%E6%B0%8F%E5%AD%A4%E5%84%BF', '/item/%E4%B9%89%E9%A1%B9', '/item/%E4%BF%9D%E5%B0%94%C2%B7%E6%9F%AF%E5%AF%9F%E9%87%91', '/item/%E9%92%A2%E9%93%81%E6%98%AF%E6%80%8E%E6%A0%B7%E7%82%BC%E6%88%90%E7%9A%84', '/item/%E5%8C%97%E4%BA%AC%E9%9D%92%E5%B9%B4%E6%8A%A5', '/item/%E5%85%B1%E9%9D%92%E5%9B%A2%E5%8C%97%E4%BA%AC%E5%B8%82%E5%A7%94%E5%91%98%E4%BC%9A', '/item/%E9%BB%84%E5%85%8B%E7%80%9B', '/item/%E4%B8%AD%E7%A7%91%E9%99%A2', '/item/%E8%B7%AF%E7%94%AC%E7%A5%A5', '/item/%E6%B5%99%E6%B1%9F%E5%A4%A7%E5%AD%A6', '/item/%E7%8E%8B%E9%87%8D%E9%B8%A3', '/item/%E6%B5%99%E6%B1%9F%E5%A4%A7%E5%AD%A6', 
# ...

# %%
sub_urls=soup.find_all("a",{"target":"_blank","href":re.compile("/item/(%.{2})+$")})
if len(sub_urls)!=0:
    his.append(random.sample(sub_urls,1))
else:
    his.pop()
print(his)
# Out:
# ['/item/%E7%BD%91%E7%BB%9C%E7%88%AC%E8%99%AB/5162711', '/item/%E6%90%9C%E7%B4%A2%E5%BC%95%E6%93%8E', '/item/%E7%BD%91%E7%AB%99', '/item/%E5%8A%A8%E7%94%BB', '/item/%E6%B8%A9%E7%91%9F%C2%B7%E9%BA%A6%E5%87%AF', '/item/%E6%81%90%E9%BE%99%E8%91%9B%E8%92%82', '/item/%E9%BB%8F%E5%9C%9F%E5%8A%A8%E7%94%BB', '/item/%E5%AE%9A%E6%A0%BC%E5%8A%A8%E7%94%BB', '/item/%E4%BE%8F%E7%BD%97%E7%BA%AA%E5%85%AC%E5%9B%AD', '/item/%E5%8F%B2%E8%92%82%E6%96%87%C2%B7%E6%96%AF%E7%9A%AE%E5%B0%94%E4%BC%AF%E6%A0%BC', '/item/%E5%A4%A7%E7%99%BD%E9%B2%A8', '/item/%E6%84%9F%E8%A7%89%E5%99%A8%E5%AE%98', '/item/%E4%BA%BA%E4%BD%93%E8%A7%A3%E5%89%96%E5%AD%A6', '/item/%E8%BF%90%E5%8A%A8%E7%B3%BB%E7%BB%9F', '/item/%E7%AD%8B%E8%86%9C%E9%97%B4%E9%9A%99', '/item/%E7%AD%8B%E8%86%9C', '/item/%E9%AA%A8%E8%BF%9E%E7%BB%93', '_blank', [<a href="/item/%E8%82%8C%E8%82%89%E6%94%B6%E7%BC%A9" target="_blank">肌肉收缩</a>], [<a href="/item/%E5%B0%BA%E9%AA%A8" target="_blank">尺骨</a>]]

# %%
sub_urls=soup.find_all("a",{"target":"_blank","href":re.compile("/item/(%.{2})+$")})
if len(sub_urls)!=0:
    his.append(random.sample(sub_urls,1)[0]['target'])
else:
    his.pop()
print(his)
# Out:
# ['/item/%E7%BD%91%E7%BB%9C%E7%88%AC%E8%99%AB/5162711', '/item/%E6%90%9C%E7%B4%A2%E5%BC%95%E6%93%8E', '/item/%E7%BD%91%E7%AB%99', '/item/%E5%8A%A8%E7%94%BB', '/item/%E6%B8%A9%E7%91%9F%C2%B7%E9%BA%A6%E5%87%AF', '/item/%E6%81%90%E9%BE%99%E8%91%9B%E8%92%82', '/item/%E9%BB%8F%E5%9C%9F%E5%8A%A8%E7%94%BB', '/item/%E5%AE%9A%E6%A0%BC%E5%8A%A8%E7%94%BB', '/item/%E4%BE%8F%E7%BD%97%E7%BA%AA%E5%85%AC%E5%9B%AD', '/item/%E5%8F%B2%E8%92%82%E6%96%87%C2%B7%E6%96%AF%E7%9A%AE%E5%B0%94%E4%BC%AF%E6%A0%BC', '/item/%E5%A4%A7%E7%99%BD%E9%B2%A8', '/item/%E6%84%9F%E8%A7%89%E5%99%A8%E5%AE%98', '/item/%E4%BA%BA%E4%BD%93%E8%A7%A3%E5%89%96%E5%AD%A6', '/item/%E8%BF%90%E5%8A%A8%E7%B3%BB%E7%BB%9F', '/item/%E7%AD%8B%E8%86%9C%E9%97%B4%E9%9A%99', '/item/%E7%AD%8B%E8%86%9C', '/item/%E9%AA%A8%E8%BF%9E%E7%BB%93', '_blank']
